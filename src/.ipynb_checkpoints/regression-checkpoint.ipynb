# %%
#諸々のインポート
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn import svm
from sklearn import ensemble, tree

# %%
#線形回帰
def linerRegression():
    df = pd.read_csv("data/address/addressList.csv", sep=",",usecols=[1,3])
    clf = LinearRegression(fit_intercept = True, normalize = False, copy_X = True, n_jobs = -1)
    for I in range(1,21):
        for line in range(len(df)):
            address = df.address[line]
            regression(address,df.lTime[line],I,clf,"linerRegression/")

# %%
#SVR(SVMを回帰に利用したもの)
def svr():
    df = pd.read_csv("data/address/addressList.csv", sep=",",usecols=[1,3])
    clf = svm.SVR(kernel='rbf')
    for I in range(1,21):
        for line in range(len(df)):
            address = df.address[line]
            regression(address,df.lTime[line],I,clf,"svr/")

# %%
#バギング ランダムフォレスト使うやつ
def bagging():
    df = pd.read_csv("data/address/addressList.csv", sep=",",usecols=[1,3])
    clf = ensemble.BaggingRegressor(tree.DecisionTreeRegressor(),n_jobs = -1)
    #clf = ensemble.BaggingRegressor(tree.DecisionTreeRegressor(), n_estimators=100, max_samples=0.3)
    for I in range(1,21):
        for line in range(len(df)):
            address = df.address[line]
            regression(address,df.lTime[line],I,clf,"bagging/")

# %%
def regression(address,lTime,I,clf,regression):
    x_train = []
    y_train = []
    df = pd.read_csv("data/address/lAddress/"+address+".csv", sep=",")
    for line in range(len(df)):
        time = df.time[line]
        if(lTime-time <= I):
            x_train.append(time)
            y_train.append(df.rssi[line])

    clf.fit(pd.DataFrame(x_train),y_train)
    x_test = []
    data = np.arange(lTime, lTime+41, 0.1)
    data = np.round(data, 1)
    for fTime in data:
        x_test.append(fTime)
    predict = clf.predict(pd.DataFrame(x_test))
    write(address,I,data,predict,regression)

# %%
def write(address,I,data,predict,regression):
    f = open("data/address/regression/"+regression+address+"_"+str(I)+".csv", 'w')
    for line in range(len(predict)):
        if(line != 0):
            f.write("\r\n")
        f.write(str(data[line])+","+str(predict[line]))
    f.close()

# %%
linerRegression()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /var/folders/lf/51xpy4vs1rlg_pf0m0ff3dbm0000gq/T/ipykernel_72523/3085952929.py in <module>
# ----> 1 linerRegression()
#
# /var/folders/lf/51xpy4vs1rlg_pf0m0ff3dbm0000gq/T/ipykernel_72523/3380004448.py in linerRegression()
#       6         for line in range(len(df)):
#       7             address = df.address[line]
# ----> 8             regression(address,df.lTime[line],I,clf,"linerRegression/")
#
# /var/folders/lf/51xpy4vs1rlg_pf0m0ff3dbm0000gq/T/ipykernel_72523/4107374867.py in regression(address, lTime, I, clf, regression)
#       2     x_train = []
#       3     y_train = []
# ----> 4     df = pd.read_csv("data/address/lAddress/"+address+".csv", sep=",")
#       5     for line in range(len(df)):
#       6         time = df.time[line]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     486
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#     490
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     221         try:
#     222             if self.low_memory:
# --> 223                 chunks = self._reader.read_low_memory(nrows)
#     224                 # destructive to chunks
#     225                 data = _concatenate_chunks(chunks)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 2 fields in line 36, saw 3

# %%
svr()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /var/folders/lf/51xpy4vs1rlg_pf0m0ff3dbm0000gq/T/ipykernel_72523/3680613987.py in <module>
# ----> 1 svr()
#
# /var/folders/lf/51xpy4vs1rlg_pf0m0ff3dbm0000gq/T/ipykernel_72523/1684237976.py in svr()
#       6         for line in range(len(df)):
#       7             address = df.address[line]
# ----> 8             regression(address,df.lTime[line],I,clf,"svr/")
#
# /var/folders/lf/51xpy4vs1rlg_pf0m0ff3dbm0000gq/T/ipykernel_72523/4107374867.py in regression(address, lTime, I, clf, regression)
#       2     x_train = []
#       3     y_train = []
# ----> 4     df = pd.read_csv("data/address/lAddress/"+address+".csv", sep=",")
#       5     for line in range(len(df)):
#       6         time = df.time[line]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     486
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#     490
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     221         try:
#     222             if self.low_memory:
# --> 223                 chunks = self._reader.read_low_memory(nrows)
#     224                 # destructive to chunks
#     225                 data = _concatenate_chunks(chunks)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 2 fields in line 36, saw 3

# %%
bagging()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /var/folders/lf/51xpy4vs1rlg_pf0m0ff3dbm0000gq/T/ipykernel_72523/3850307677.py in <module>
# ----> 1 bagging()
#
# /var/folders/lf/51xpy4vs1rlg_pf0m0ff3dbm0000gq/T/ipykernel_72523/2714202809.py in bagging()
#       7         for line in range(len(df)):
#       8             address = df.address[line]
# ----> 9             regression(address,df.lTime[line],I,clf,"bagging/")
#
# /var/folders/lf/51xpy4vs1rlg_pf0m0ff3dbm0000gq/T/ipykernel_72523/4107374867.py in regression(address, lTime, I, clf, regression)
#       2     x_train = []
#       3     y_train = []
# ----> 4     df = pd.read_csv("data/address/lAddress/"+address+".csv", sep=",")
#       5     for line in range(len(df)):
#       6         time = df.time[line]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     486
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#     490
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     221         try:
#     222             if self.low_memory:
# --> 223                 chunks = self._reader.read_low_memory(nrows)
#     224                 # destructive to chunks
#     225                 data = _concatenate_chunks(chunks)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 2 fields in line 36, saw 3
