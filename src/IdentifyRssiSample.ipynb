# %%
import pandas as pd
import numpy as np

capture = pd.read_csv("data/capture/single/move/csv/move0.csv", sep=",")
capture.head
# Out:
# <bound method NDFrame.head of       07:cb:32:83:6e:4a          0.0  -48
# 0     7a:21:9a:e6:80:fe     0.133021  -50
# 1     72:9c:60:38:2f:7f     0.921113  -77
# 2     7a:21:9a:e6:80:fe     5.020179  -60
# 3     72:9c:60:38:2f:7f     5.037497  -76
# 4     07:cb:32:83:6e:4a     5.158409  -58
# 5     72:9c:60:38:2f:7f     9.993197  -74
# 6     07:cb:32:83:6e:4a    10.046546  -55
# 7     7a:21:9a:e6:80:fe    10.179598  -54
# 8     58:b4:ad:58:e0:0c    13.627582  -76
# 9     58:b4:ad:58:e0:0c    15.067529  -82
# 10    7a:21:9a:e6:80:fe    15.082072  -47
# 11    07:cb:32:83:6e:4a    15.212811  -47
# 12    72:9c:60:38:2f:7f    15.517688  -76
# 13    07:cb:32:83:6e:4a    20.036221  -54
# 14    72:9c:60:38:2f:7f    20.475624  -77
# 15    58:b4:ad:58:e0:0c    21.114399  -77
# 16    7a:21:9a:e6:80:fe    21.114986  -60
# 17    58:b4:ad:58:e0:0c    21.381432  -84
# 18    72:9c:60:38:2f:7f    25.143606  -77
# 19    7a:21:9a:e6:80:fe    25.199436  -60
# 20    07:cb:32:83:6e:4a    25.214746  -70
# ...
